# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %% [markdown]
# In this post, I will analyze the Starbucks Dataset using the CRISP-DM Process. I will aim to answer a few business questions, by exploring the dataset using Data Visualization, and Modeling. The questions that I am interested in exploring are:
#
# 1. How does Gender influence how much someone spends at Starbucks? Do men spend more than women, or the other way around?
# 2. How many people view and complete offers? And how many people complete offers without opening them first?
# 3. What are the attributes that most contribute to someone's spending habits at Starbucks?
#
# These questions help us with a *Business Understanding* of the domain.

# %% [markdown]
# Let's start by first importing the required packages, and loading the datasets.

# %%
import pandas as pd
import numpy as np
import math
import json
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split;
from sklearn.preprocessing import StandardScaler;
from sklearn.svm import SVR;
from sklearn.model_selection import GridSearchCV;
from sklearn.metrics import r2_score;
from sklearn.ensemble import RandomForestRegressor;

# %matplotlib inline

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# ### Exploring the Data
#
# We'll look at these datasets by printing out the first few rows of each.

# %%
portfolio.head()
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
#
#                                  id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5

# %%
profile.head()
# Out:
#    age  became_member_on gender                                id    income
# 0  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783       NaN
# 1   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2  118          20180712   None  38fe809add3b4fcf9315a9694bb96ff5       NaN
# 3   75          20170509      F  78afa995795e4d85b5d9ceeca43f5fef  100000.0
# 4  118          20170804   None  a03223e636434f42ac4c3df47e8bac43       NaN

# %%
transcript.head()
# Out:
#             event                            person  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                                               value
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}

# %% [markdown]
# We'll now visualize these datasets by plotting correlation plots in Portfolio and Profile.

# %%
sns.pairplot(portfolio, hue='offer_type')

# %% [markdown]
# We can see that **Discount** offers last the longest, and **Bogo** offers have the highest reward.

# %%
sns.pairplot(profile.dropna(), hue='gender')

# %% [markdown]
# There is a lot of data for the Profiles, and we can see some interesting trends from it. For instance, in terms of **age**, most female purchasers tend to be younger than most male purchasers.
#
# To explore the Transcript dataset, I'll look at the distribution of the types of offers that people respond to. I will plot the channels corresponding to the offers, and the type of offer they are.

# %%
# Replace missing offer id's with 0
all_offers = transcript.value.apply(lambda x: x['offer id'] if 'offer id' in x else 0).values
all_offers = all_offers[all_offers != 0];
portfolio_group = portfolio.groupby('id')[['offer_type', 'channels']];

# Flatten the channel names into an array
all_channels = [portfolio_group.get_group(ide).values[0][1] for ide in all_offers];
all_channels = [row for subrow in all_channels for row in subrow]

# Flatten the offer types into an array
all_types = [portfolio_group.get_group(ide).values[0][0] for ide in all_offers];
del all_offers, portfolio_group

# %%
plt.rcParams["figure.figsize"] = (10,4)

fig, (ax1, ax2) = plt.subplots(ncols = 2, sharey = True)

sns.countplot(all_channels, ax=ax1)
sns.countplot(all_types, ax=ax2)

# %% [markdown]
# We see with these distributions that the most offers are sent through **Email** and **Mobile**. **Informational** offers are much more uncommon than the other types of offers as well. I'd like to explore the data further by filtering out only transactions that have been *viewed* and *completed*.

# %%
del all_types, all_channels;

# %% [markdown]
# ### Preparing the data
#
# As we can already see through the initial exploration, there are a lot of areas that need to be cleaned. This will include formatting the text columns, and removing missing values.
#
# We'll start with the **Portfolio** dataset. We see that **channels** are grouped as list values. I will separate the individual values and dummy-fy them. The same will be done for **offer types**. We'll then drop the original columns and append the newer one-hot encoded columns.

# %%
# Dummy-fy channel attributes
portfolio_channels = portfolio['channels'].apply(lambda x: ' '.join(x)).str.get_dummies(' ');
portfolio_channels.columns = ['channel_' + col for col in portfolio_channels.columns];

# Dummy-fy offer type attributes
portfolio_offertype = portfolio['offer_type'].str.get_dummies()
portfolio_offertype.columns = ['offer_' + col for col in portfolio_offertype.columns];

# %%
# Add dummy columns and drop existing
portfolio = pd.concat([portfolio, portfolio_channels, portfolio_offertype], axis=1);
portfolio = portfolio.drop(['channels', 'offer_type'], axis=1);
portfolio.head()
# Out:
#    difficulty  duration                                id  reward  \
# 0          10         7  ae264e3637204a6fb9bb56bc8210ddfd      10
# 1          10         5  4d5c57ea9a6940dd891ad53e9dbe8da0      10
# 2           0         4  3f207df678b143eea3cee63160fa8bed       0
# 3           5         7  9b98b8c7a33c4b65b9aebfe6a799e6d9       5
# 4          20        10  0b1e1539f2cc45b7b9fa7c272da2e1d7       5
#
#    channel_email  channel_mobile  channel_social  channel_web  offer_bogo  \
# 0              1               1               1            0           1
# 1              1               1               1            1           1
# 2              1               1               0            1           0
# 3              1               1               0            1           1
# 4              1               0               0            1           0
#
#    offer_discount  offer_informational
# 0               0                    0
# 1               0                    0
# 2               0                    1
# 3               0                    0
# 4               1                    0

# %%
del portfolio_channels, portfolio_offertype

# %%
portfolio.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# The above sample shows our final cleaned **Portfolio** dataset. The above call also shows that there are no missing values to be removed.
#
# Next, we look at the **Profile** dataset. Let's start by looking at missing value counts, and dropping these rows.

# %%
print('# missing values of income, gender:')
profile['income'].isna().sum(), profile['gender'].isna().sum()
# Out:
# # missing values of income, gender:
# (2175, 2175)

# %%
profile = profile.dropna(axis=0, subset=['gender', 'income']);

# %% [markdown]
# The **Profile** dataset also has a column for membership data, **became_member_on**. I will separate out the date strings into *Year*, *Month*, and *Day*, and keep them as integer values. For **gender**, we will dummy-fy the values into separate one-hot-encodings.

# %%
profile_gender = profile['gender'].str.get_dummies()
profile_gender.columns = ['gender_' + col for col in profile_gender.columns];

# %%
# Separate date attributes into year, month, and day, converting to integers.
profile_date = profile['became_member_on'];

profile_year = profile_date.apply(lambda d: str(d)).str[0:4].astype('int').rename('member_year');
profile_month = profile_date.apply(lambda d: str(d)).str[4:6].astype('int').rename('member_month');
profile_day = profile_date.apply(lambda d: str(d)).str[6:8].astype('int').rename('member_day');

# %%
profile = pd.concat([profile, profile_gender, profile_year, profile_month, profile_day], axis=1);

# %%
profile = profile.drop(['became_member_on', 'gender'], axis=1);

# %%
del profile_gender, profile_year, profile_month, profile_day

# %%
profile.head()
# Out:
#     age                                id    income  gender_F  gender_M  \
# 1    55  0610b486422d4921ae7d2bf64640c50b  112000.0         1         0
# 3    75  78afa995795e4d85b5d9ceeca43f5fef  100000.0         1         0
# 5    68  e2127556f4f64592b11af22de27a7932   70000.0         0         1
# 8    65  389bc3fa690240e798340f5a15918d5c   53000.0         0         1
# 12   58  2eeac8d8feae4a8cad5a6af0499a211d   51000.0         0         1
#
#     gender_O  member_year  member_month  member_day
# 1          0         2017             7          15
# 3          0         2017             5           9
# 5          0         2018             4          26
# 8          0         2018             2           9
# 12         0         2017            11          11

# %% [markdown]
# The **Transcript** dataset is bigger and has more required cleaning. The column **value** is stored as a dictionary. The values in the dictionaries are inconsistent, with both `offer_id` and `offer id` stored. Once we clean those, they can be converted into columns. The **event** column will also be dummy-fied, and column names standardized.

# %%
transcript_event = transcript['event'].str.get_dummies();
transcript_event.columns = ['event_' + '_'.join(col.split(' ')) for col in transcript_event.columns];

# %%
# standardize "offer id" column names
def transcript_value_clean(x_dict):
    if 'offer id' in x_dict:
        x_dict['offer_id'] = x_dict['offer id'];
        del x_dict['offer id'];
    return x_dict;

transcript_values = transcript['value'].apply(lambda x: transcript_value_clean(x));
transcript_values = pd.DataFrame(list(transcript_values.values));

# %% [markdown]
# Amount values are stored in both **reward** and **amount** columns, and they distinguish different types of transactions. Instead of having both, we will merge both into a single column, and use new columns *is_reward* and *is_amount* for distinguishing them. Finally, if there is an **offer_id** associated with a transaction, *has_offer* will store it, and null values will be replaced with a 0.

# %%
transcript_values['is_reward'] = transcript_values['reward'].apply(lambda x: int(not np.isnan(x)));

# %%
# merge amount and reward columns
transcript_values['is_amount'] = transcript_values['amount'].apply(lambda x: int(not np.isnan(x)));
transcript_values['amount'] = transcript_values[['amount', 'reward']].apply(lambda x: x[0] if np.isnan(x[1]) else x[1], axis=1)

# %%
# filling null offer ids with "0"
transcript_values['has_offer'] = transcript_values['offer_id'].apply(lambda x: int(not pd.isna(x)));
transcript_values['offer_id'] = transcript_values['offer_id'].apply(lambda x: '0' if pd.isna(x) else x);

# %%
transcript = pd.concat([transcript, transcript_values, transcript_event], axis=1);

# %%
transcript = transcript.drop(['value', 'event', 'reward'], axis=1);

# %%
del transcript_value_clean, transcript_values, transcript_event

# %%
transcript.head()
# Out:
#                              person  time  amount  \
# 0  78afa995795e4d85b5d9ceeca43f5fef     0     NaN
# 1  a03223e636434f42ac4c3df47e8bac43     0     NaN
# 2  e2127556f4f64592b11af22de27a7932     0     NaN
# 3  8ec6ce2a7e7949b1bf142def7d0e0586     0     NaN
# 4  68617ca6246f4fbc85e91a2a49552598     0     NaN
#
#                            offer_id  is_reward  is_amount  has_offer  \
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9          0          0          1
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7          0          0          1
# 2  2906b810c7d4411798c6938adc9daaa5          0          0          1
# 3  fafdcd668e3743c1bb461111dcafc2a4          0          0          1
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0          0          0          1
#
#    event_offer_completed  event_offer_received  event_offer_viewed  \
# 0                      0                     1                   0
# 1                      0                     1                   0
# 2                      0                     1                   0
# 3                      0                     1                   0
# 4                      0                     1                   0
#
#    event_transaction
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %% [markdown]
# The final **Portfolio**, **Profile**, and **Transcript** datasets are all cleaned, and can be used for further exploration. We'll now create some new datasets from these. These will be
#
# - Transactions Only - Store only transactions, not associated with an offer, along with demographic data on the users.
#
# - Transcript by Group - Store transactions by grouping them by their offer, and the person it was sent to.

# %%
transcript_profile = pd.merge(transcript, profile, left_on='person', right_on='id')

# %%
# keep only records of actual transactions, and keep integer columns
transaction_data_only = transcript_profile[transcript_profile.event_transaction == 1];
transaction_data_only = transaction_data_only.select_dtypes(exclude=['object']);

# separate into male and female dataframes
transaction_data_f = transaction_data_only[transaction_data_only.gender_F == 1]
transaction_data_m = transaction_data_only[transaction_data_only.gender_M == 1]

transaction_data_only.head()
# Out:
#    time  amount  is_reward  is_amount  has_offer  event_offer_completed  \
# 0     0    0.83          0          1          0                      0
# 1     6    1.44          0          1          0                      0
# 2    12    4.56          0          1          0                      0
# 3    84    1.53          0          1          0                      0
# 4    90    0.50          0          1          0                      0
#
#    event_offer_received  event_offer_viewed  event_transaction  age   income  \
# 0                     0                   0                  1   20  30000.0
# 1                     0                   0                  1   20  30000.0
# 2                     0                   0                  1   20  30000.0
# 3                     0                   0                  1   20  30000.0
# 4                     0                   0                  1   20  30000.0
#
#    gender_F  gender_M  gender_O  member_year  member_month  member_day
# 0         1         0         0         2016             7          11
# 1         1         0         0         2016             7          11
# 2         1         0         0         2016             7          11
# 3         1         0         0         2016             7          11
# 4         1         0         0         2016             7          11

# %%
plt.rcParams["figure.figsize"] = (12,4)

fig, (ax1, ax2) = plt.subplots(ncols = 2)

# plotting a Box Plot of amounts by gender
g = sns.boxplot(x="gender_F", y="amount",
            hue="gender_F", palette=["m", "g"],
            data=transaction_data_only, ax=ax1)

# set a log Y scale
g.set_yscale('log')
g.legend().set_title('Gender')
for t, l in zip(g.legend().texts, ['Male', 'Female']): t.set_text(l)

# plot title and axis
plt.title('Amount spent on transactions by Gender')
plt.xlabel('Gender')
plt.ylabel('Amount')
plt.xticks([[]])

# plotting a Bar Plot of number of transactions by gender
h = sns.countplot(transaction_data_only['gender_F'], ax=ax2)

# plot title and axis
plt.title('Number of Transactions by Gender')
plt.xlabel('Gender')
plt.ylabel('Transactions')

plt.xticks([0, 1], ['Male', 'Female'])

# Create a new DataFrame of stat details on required attributes
description_columns = ['amount', 'age', 'income']
description_labels = [cat + '_' + gen for cat in ['Male', 'Female'] for gen in description_columns]
reorder_columns = [gen + '_' + cat for cat in description_columns for gen in ['Male', 'Female']]

# Separate into stats from Female and Male transactions
description = pd.concat([transaction_data_m[['amount', 'age', 'income']].describe(), 
           transaction_data_f[['amount', 'age', 'income']].describe()], axis=1);
description.columns = description_labels;

plt.show()

# %%
description[reorder_columns]
# Out:
#         Male_amount  Female_amount      Male_age    Female_age    Male_income  \
# count  72794.000000   49382.000000  72794.000000  49382.000000   72794.000000
# mean      11.606600      17.490077     50.725650     55.637986   58491.317966
# std       28.964542      35.342611     17.755604     17.776608   19048.170156
# min        0.050000       0.050000     18.000000     18.000000   30000.000000
# 25%        2.570000       7.970000     37.000000     43.000000   43000.000000
# 50%        7.050000      15.000000     52.000000     56.000000   56000.000000
# 75%       16.220000      22.120000     64.000000     68.000000   70000.000000
# max      977.780000    1062.280000    100.000000    101.000000  120000.000000
#
#        Female_income
# count   49382.000000
# mean    66813.960552
# std     21965.016643
# min     30000.000000
# 25%     51000.000000
# 50%     65000.000000
# 75%     82000.000000
# max    120000.000000

# %% [markdown]
# The above three charts answer our questions about **Gender**. We see in the first plot that *Women* spend more on transactions then *Men* do. The interesting thing in the second chart is that it shows that there are a lot more records of purchases by men than those by women.
#
# The final chart (table)  gives more detailed statistics on **Amount**, **Age**, and **Income** separated by **Gender**. It shows that *Women* clearly spend more than *Men* do, with higher mean and deviation. Contrary to the early plot on raw data, we see that the **age** of most spenders is similar for both men and women. Finally, the biggest disparity we see is in **Income**. Higher mean and 25/50/70 percentage quantile shows that the average Female spender earns more than the average Male spender.
#
# ***This answers our first question on the influence of gender of purchases. Women spend more at Starbucks then Men do, with an average difference of about 6 dollars per purchase***.

# %% [markdown]
# Next, let's look at the **Transcript** dataset in more detail. We saw earlier that the dataset has different types of events associated with a transaction. This includes when an offer is received, viewed, and completed, as well as when it is an actual purchase. In this step, we are going to look for *completion trails*, as in for every offer that is sent to a person, how often to do they actually view and complete the offer by making purchases for it.

# %%
transcript_portfolio = pd.merge(transcript, portfolio, left_on='offer_id', right_on='id', how='left')
transcript_by_group = transcript_portfolio.groupby(['person', 'offer_id'])

# %%
# %%time

completion_details = [];

'''
Go through each group in the transaction grouping. Because iterating can be slow, 
we will use vectorized operations inside the main loop.
'''
for i, g in transcript_by_group:
    
    record = {};
    
    # Record status based on weather the offer has been viewed
    if g[['event_offer_received', 'event_offer_viewed', 'event_offer_completed']].sum(axis=0).sum() == 3:
        record['status'] = 'viewed_and_completed';
    elif (g[['event_offer_received', 'event_offer_completed']].sum(axis=0).sum() == 2) and 'status' not in record:
        record['status'] = 'not_viewed_and_completed';
    else:
        record['status'] = 'no_offer';
    
    # Get required details
    person_id, offer_id = g['person'].iloc[0], g['offer_id'].iloc[0];
    first_purchase, last_purchase = g['time'].min(), g['time'].max();
    
    # Get all transactions corresponding to the person
    try:
        person_transactions = transactions_only.get_group(person_id);
    except KeyError:
        offer_transactions = [];
    
    # Filter out transactions that are within the time window of the offer
    offer_transactions = person_transactions[(person_transactions.time > first_purchase) \
                                             & (person_transactions.time < last_purchase)];

    # Store these details into the dictionary
    record['num_transactions'] = len(offer_transactions);
    record['person_id'], record['offer_id'] = person_id, offer_id;
    record['first_purchase'], record['last_purchase'] = first_purchase, last_purchase;
    
    #print(person_id, offer_id, num_transactions)
    completion_details.append(record);

print('Completed forming transactions');
# Out:
# Completed forming transactions
# CPU times: user 5min 13s, sys: 40.3 ms, total: 5min 13s
# Wall time: 5min 14s

# %%
completion_details_df = pd.DataFrame(completion_details);

# %% [markdown]
# Having computed the details view, we will plot charts about them. First, we will look at the amount of transactions made on each status. Second, the number of transactions made when they were done corresponding to an offer. And third, a sample of rows on purchases made when an offer was completed without any transactions.

# %%
plt.rcParams["figure.figsize"] = (12,4)

fig, (ax1, ax2) = plt.subplots(ncols = 2)

# Plotting the status of offers
g = sns.countplot(completion_details_df['status'], ax=ax1);
g.set_xticklabels(labels = ['No Offer', 'Viewed and Completed Offer', 'Did not view but completed offer'], rotation=45)

# Plotting number of transactions made when associated with an offer
h = sns.countplot(completion_details_df[completion_details_df.status != 'no_offer']['num_transactions'], ax=ax2)

plt.show()

# %%
for val in np.unique(completion_details_df['status']):
    print(val , ' : ' , ((completion_details_df['status'] == val).sum() / len(completion_details_df))*100, '%')
# Out:
# no_offer  :  64.9162346931 %
# not_viewed_and_completed  :  9.81018205494 %
# viewed_and_completed  :  25.2735832519 %

# %%
completed_offers_with_zero_purchases = completion_details_df[(completion_details_df.status != 'no_offer') & (completion_details_df.num_transactions == 0)];
completed_offers_with_zero_purchases = pd.merge(completed_offers_with_zero_purchases, portfolio[['id', 'offer_type']], left_on='offer_id', right_on='id')
completed_offers_with_zero_purchases.drop(['offer_id', 'person_id', 'id'], axis=1).sample(5)
# Out:
#        first_purchase  last_purchase  num_transactions  \
# 16192             168            336                 0
# 136               576            642                 0
# 3762              408            450                 0
# 14127               0             12                 0
# 460               336            378                 0
#
#                          status     offer_type
# 16192  not_viewed_and_completed  informational
# 136    not_viewed_and_completed       discount
# 3762       viewed_and_completed       discount
# 14127      viewed_and_completed       discount
# 460    not_viewed_and_completed       discount

# %% [markdown]
# The above charts answer several questions. In the first chart, we see that apart from users who make a purchase not corresponding to an offer, *more people actually complete an offer without receiving it first*. However, around 8,000 people still *utilize offers*.
#
# The second chart shows how many transactions are made to complete offers. We can see that thre is a clear skew on 0 transactions. Apart from those, *most offers are completed within 1-2 purchases*. I finally looked at a sample of rows where an offer was completed without any transactions. This showed that the dataset may contain incomplete records.
#
# ***This answers our 2nd question. 25% of people view and complete offers, while 10% of people complete offers without viewing them first.***

# %% [markdown]
# ### Modeling the data
#
# With our cleaned data, we can now use Supervised Models to try to predict price. Because **price** is a continous variable, we will need to use a regression model. First, we'll need to separate the data into X and Y.

# %%
# Time is relative and will likely not be useful. Amount will be separated into the Y column.

data_x = transaction_data_only.drop(['amount', 'time'], axis=1);
data_y = transaction_data_only['amount'];

# %% [markdown]
# We'll now use a Scaler function to normalize the attributes.

# %%
scaler = StandardScaler();
data_x = scaler.fit_transform(data_x);

# %%
data_x.shape, data_y.shape
# Out:
# ((123957, 15), (123957,))

# %% [markdown]
# And finally, separate the X and Y into a Train/Test split.

# %%
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.33);

# %%
X_train.shape, X_test.shape
# Out:
# ((83051, 15), (40906, 15))

# %% [markdown]
# For modeling, let's start by first using a **Support Vector Machine (SVM)** to fit a model to the data. I will use a Polynomial Regression model. The metric I decided to use is a **R2** score, which works well on continious output.

# %%
# %%time

sv_model = SVR(kernel='poly', degree=7);
sv_model.fit(X_train, y_train);
print('SVR model trained on 7-degree poly kernel')
# Out:
# SVR model trained on 7-degree poly kernel
# CPU times: user 16min 16s, sys: 318 ms, total: 16min 16s
# Wall time: 16min 21s

# %%
# %%time

y_preds_svr = sv_model.predict(X_test);
print('SVR Model R2 score: ' , r2_score(y_test, y_preds_svr))
# Out:
# SVR Model R2 score:  0.0791369487837
# CPU times: user 1min 15s, sys: 8.14 ms, total: 1min 15s
# Wall time: 1min 16s

# %% [markdown]
# Although the SVM provided good results, we cannot view feature importance because the kernel is non-linear. Feature importance is useful for us because it will help us understand which attributes most contribute to a predicted label. Let's use a different model for this, such as a **Random Forest**.

# %%
# %%time

rf_model = RandomForestRegressor(n_estimators=100, max_depth=20, max_features=15, min_samples_split=5);
rf_model.fit(X_train, y_train);
print('RF Model trained with 10 estimators')
# Out:
# RF Model trained with 10 estimators
# CPU times: user 17.3 s, sys: 104 ms, total: 17.4 s
# Wall time: 17.7 s

# %%
# %%time

y_preds_rf = rf_model.predict(X_test);
print('RF Model R2 score: ' , r2_score(y_test, y_preds_rf))
# Out:
# RF Model R2 score:  -0.0823391370849
# CPU times: user 1.03 s, sys: 4 ms, total: 1.03 s
# Wall time: 1.04 s

# %% [markdown]
# The R2 Score is not as good as that obtained with the SVM, so we should try to tune the model to find parameters that provide the best results. For this, we can use a **Grid Search**. The parameters we will tune are
#
# - Number of Estimators, between *10, 50, and 100*
# - Maximum Depth of a tree, between *5, 10, 30, and 80*
# - Maximum Number of Features in a tree, between *1, 3, 8, and 15*
# - Minimum Samples to split on, between *3, 5, 10, 30, 50, and 100*

# %%
params = {'n_estimators' : [10, 50, 100], 'max_depth' : [5, 10, 30, 80], \
          'max_features': [1, 3, 8, 15], 'min_samples_split': [3, 5, 10, 30, 50, 100]}

g_rfm = RandomForestRegressor(random_state=1024);
g_src = GridSearchCV(g_rfm, params, verbose=10, cv=5, scoring='r2');

# %%
g_src.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=10, score=0.04195848986474615, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=10, score=0.06739797845179119, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=10
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=10, score=0.05894666067186671, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=10
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=10, score=0.06672480454842156, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=10
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=10, score=0.05059042354450327, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=50
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.2s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=50, score=0.0398031472289786, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=50
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    2.3s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=50, score=0.06375849803911726, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=50
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    3.3s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=50, score=0.0548656875968736, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=50
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    4.4s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=50, score=0.06487309741927094, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=50
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    5.3s remaining:    0.0s
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=50, score=0.049589858106953155, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=100, score=0.03865628859128911, total=   2.0s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=100, score=0.06206701343013754, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=100, score=0.05464342231419017, total=   1.5s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=100, score=0.062073195865690045, total=   1.5s
# [CV] max_depth=5, max_features=1, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=3, n_estimators=100, score=0.04850556774918413, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=10, score=0.04214976292417538, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=10, score=0.0656093680807256, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=10, score=0.05805097380616242, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=10, score=0.06672480454842156, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=10, score=0.05059042354450327, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=50, score=0.03970801489328135, total=   1.1s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=50, score=0.06349023523735342, total=   1.1s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=50, score=0.054579285233655295, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=50, score=0.06448975058987139, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=50, score=0.050479296073004165, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=100, score=0.03851015644735367, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=100, score=0.061562522511995565, total=   1.8s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=100, score=0.05441159001169926, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=100, score=0.062340270847853096, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=5, n_estimators=100, score=0.048970854405548825, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=10, score=0.04027319018275721, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=10, score=0.06442390624398464, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=10, score=0.057922601755217795, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=10, score=0.06672087377617542, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=10, score=0.05060844727946112, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=50, score=0.03842864062843665, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=50, score=0.06403979035575325, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=50, score=0.055578277072598326, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=50, score=0.06500549937122202, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=50, score=0.04916702596272826, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=100, score=0.03808243607587647, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=100, score=0.061715958206500554, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=100, score=0.05498422004288006, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=100, score=0.0629818102882237, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=10, n_estimators=100, score=0.04832295980108192, total=   1.9s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=10, score=0.040038608077547444, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=10, score=0.06381875464268738, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=10, score=0.05933597113639533, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=10, score=0.06630340283878422, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=10, score=0.051250649446878294, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=50, score=0.036349825948279624, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=50, score=0.06392990755836403, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=50, score=0.056322923589026574, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=50, score=0.0643001063008869, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=50, score=0.04721806683110208, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=100, score=0.037141733507830677, total=   1.5s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=100, score=0.06168565764090683, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=100, score=0.05504857732200452, total=   1.5s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=100, score=0.06245839551673826, total=   1.5s
# [CV] max_depth=5, max_features=1, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=30, n_estimators=100, score=0.047234637601652696, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=10, score=0.042004792273186764, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=10, score=0.06457322608496907, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=10, score=0.059328245427551884, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=10, score=0.06934507926571387, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=10, score=0.05408779766523053, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=50, score=0.03811577437948299, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=50, score=0.0629001897662348, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=50, score=0.055942511408610396, total=   1.1s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=50, score=0.06477704698871689, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=50, score=0.049726865737385606, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=100, score=0.03765966082432404, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=100, score=0.06109783980315919, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=100, score=0.0546590570082901, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=100, score=0.06199821166707986, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=50, n_estimators=100, score=0.048046008522145245, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=10, score=0.041779323711674254, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=10, score=0.06364952187297956, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=10, score=0.060471363006780465, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=10, score=0.06672999881608177, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=10, score=0.05182219530400456, total=   0.2s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=50, score=0.03799711565164865, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=50, score=0.0629880940195583, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=50, score=0.05449657730673829, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=50, score=0.0643081066213611, total=   0.8s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=50, score=0.05031305363953198, total=   0.9s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=100, score=0.03718520342266862, total=   1.8s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=100, score=0.06116287498486883, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=100, score=0.0531541050921327, total=   1.6s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=100, score=0.062192494168855084, total=   1.7s
# [CV] max_depth=5, max_features=1, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=1, min_samples_split=100, n_estimators=100, score=0.04802847519436304, total=   1.6s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=10, score=0.04560045777419508, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=10, score=0.07025470753433782, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=10, score=0.06119209273013526, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=10, score=0.0716252102864473, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=10, score=0.057803326140186795, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=50, score=0.04426518119995004, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=50, score=0.07052437447131077, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=50, score=0.061630272122604635, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=50, score=0.0725164376054519, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=50, score=0.05804953886427733, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=100, score=0.043581571393728646, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=100, score=0.07043159401535037, total=   2.3s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=100, score=0.06205583901143641, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=100, score=0.07204834023148932, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=3, n_estimators=100, score=0.057262194928108356, total=   1.9s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=10, score=0.04566219846485198, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=10, score=0.06968790434172056, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=10, score=0.061195850426355114, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=10, score=0.07107543085836066, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=10, score=0.057803326140186795, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=50, score=0.044321496432531915, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=50, score=0.07050825029369268, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=50, score=0.06181981389956026, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=50, score=0.07285243405366626, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=50, score=0.05777441434286734, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=0.04359733801616117, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=0.07019016516275434, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=0.06199561551019506, total=   2.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=0.07215809686499541, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=0.05681427722867749, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=10, score=0.04564919419724778, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=10, score=0.0711235110599725, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=10, score=0.06135730848020993, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=10, score=0.07126894678228024, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=10, score=0.057994916999503876, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=50, score=0.04471858587374922, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=50, score=0.07092797567025422, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=50, score=0.061864063204131625, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=50, score=0.07295193356670537, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=50, score=0.057101684255645324, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=100, score=0.04413193735549026, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=100, score=0.07032991537732647, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=100, score=0.06211817669711639, total=   2.2s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=100, score=0.0726401834822098, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=10, n_estimators=100, score=0.05637182862154333, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=10, score=0.045506977847912466, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=10, score=0.07130205090231179, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=10, score=0.0649696609019913, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=10, score=0.07133472437460608, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=10, score=0.057650279229138235, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=50, score=0.044630078357815406, total=   0.9s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=50, score=0.07037806349593445, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=50, score=0.06281435403619595, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=50, score=0.07249334286439357, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=50, score=0.05729150323498211, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=100, score=0.044194713079365844, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=100, score=0.07039679628741025, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=100, score=0.0625956582177275, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=100, score=0.07190199369293093, total=   2.2s
# [CV] max_depth=5, max_features=3, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=30, n_estimators=100, score=0.05658858487284746, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=10, score=0.04479099291048838, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=10, score=0.0708464483120339, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=10, score=0.06508739655917994, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=10, score=0.07193151901049954, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=10, score=0.05744697665151699, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=50, score=0.04286443255966732, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=50, score=0.07175012151444637, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=50, score=0.06318593751211177, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=50, score=0.07279104584906138, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=50, score=0.05778910218112032, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=100, score=0.04346613260665799, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=100, score=0.07055398132618773, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=100, score=0.061946530005991596, total=   1.8s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=100, score=0.07221958718059529, total=   2.1s
# [CV] max_depth=5, max_features=3, min_samples_split=50, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=50, n_estimators=100, score=0.057023955377508706, total=   1.8s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=10, score=0.0468091512324732, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=10, score=0.07193578783086507, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=10, score=0.06428160011854023, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=10, score=0.07280153455257177, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=10
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=10, score=0.057459351342033504, total=   0.2s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=50, score=0.0437777254747056, total=   0.9s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=50, score=0.07082053576907665, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=50, score=0.06326402243313456, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=50, score=0.07238990161776726, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=50
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=50, score=0.05579198551974107, total=   1.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=100, score=0.0442183306328775, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=100, score=0.06981308086613525, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=100, score=0.062218975446797775, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=100, score=0.07138876003129446, total=   2.0s
# [CV] max_depth=5, max_features=3, min_samples_split=100, n_estimators=100
# [CV]  max_depth=5, max_features=3, min_samples_split=100, n_estimators=100, score=0.05577940316437535, total=   2.2s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=10, score=0.04943349180901779, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=10, score=0.07596711871352102, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=10, score=0.06623475032978032, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=10, score=0.07725107777156437, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=10, score=0.06125214627985154, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=50, score=0.04972830318911026, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=50, score=0.0757566429105625, total=   1.9s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=50, score=0.06629139472922885, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=50, score=0.07701669830147873, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=50, score=0.061723000886831914, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=100, score=0.04988779253365094, total=   3.6s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=100, score=0.07598387018447528, total=   3.7s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=100, score=0.06608877103259525, total=   3.5s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=100, score=0.07743471527051049, total=   3.5s
# [CV] max_depth=5, max_features=8, min_samples_split=3, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=3, n_estimators=100, score=0.06138462955916335, total=   3.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=10, score=0.04927223838096262, total=   0.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=10, score=0.07596711871352102, total=   0.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=10, score=0.06623475032978032, total=   0.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=10, score=0.07770105777975755, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=10, score=0.06125214627985154, total=   0.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=50, score=0.04975728003641211, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=50, score=0.07574660285238555, total=   1.6s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=50, score=0.0663483568587715, total=   1.6s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=50, score=0.07735095882357956, total=   1.9s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=50, score=0.0618817591005546, total=   1.6s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=100, score=0.0498712662214007, total=   3.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=100, score=0.0759835753704855, total=   3.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=100, score=0.06619977309011693, total=   3.3s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=100, score=0.07757240621803796, total=   3.5s
# [CV] max_depth=5, max_features=8, min_samples_split=5, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=5, n_estimators=100, score=0.0614790168579592, total=   3.8s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=10, score=0.04877832987682007, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=10, score=0.07598353726361529, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=10, score=0.06644949636785147, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=10, score=0.07781995864070534, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=10, score=0.06123955389778202, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=50, score=0.04962822635973352, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=50, score=0.07582438191233709, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=50, score=0.06642770628410388, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=50, score=0.07734729843065669, total=   1.9s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=50, score=0.06185887177518046, total=   2.3s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=100, score=0.04973573311687496, total=   4.2s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=100, score=0.07593138706275471, total=   4.0s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=100, score=0.06627242287519663, total=   3.4s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=100, score=0.07759669965728, total=   3.5s
# [CV] max_depth=5, max_features=8, min_samples_split=10, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=10, n_estimators=100, score=0.061530480370803664, total=   3.5s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=10, score=0.049106835803587656, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=10, score=0.07593706352356322, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=10, score=0.0666216160822739, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=10, score=0.07769407387937644, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=10, score=0.06116646427529382, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=50, score=0.049659772708407934, total=   2.3s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=50, score=0.07614403311104145, total=   1.9s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=50, score=0.06661939361679547, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=50, score=0.0773599513678439, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=50, score=0.06220565938863054, total=   1.6s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=100, score=0.04982538358662658, total=   3.4s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=100, score=0.07602171618568743, total=   3.6s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=100, score=0.06677562321869857, total=   3.5s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=100, score=0.07749556907063349, total=   3.8s
# [CV] max_depth=5, max_features=8, min_samples_split=30, n_estimators=100
# [CV]  max_depth=5, max_features=8, min_samples_split=30, n_estimators=100, score=0.06181807642090398, total=   3.4s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=10, score=0.048951724654079376, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=10, score=0.0752629729849984, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=10, score=0.06614646112058387, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=10, score=0.07803672488024072, total=   0.4s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=10
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=10, score=0.0612333652687751, total=   0.3s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=50, score=0.0494902247260276, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=50, score=0.0762927045739421, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=50, score=0.0667264012353963, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=50, score=0.07742163034028493, total=   1.7s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=50
# [CV]  max_depth=5, max_features=8, min_samples_split=50, n_estimators=50, score=0.062311787244623607, total=   1.8s
# [CV] max_depth=5, max_features=8, min_samples_split=50, n_estimators=100
# ...
# [CV] max_depth=80, max_features=15, min_samples_split=3, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=3, n_estimators=100, score=-0.12998547505518454, total=  16.3s
# [CV] max_depth=80, max_features=15, min_samples_split=3, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=3, n_estimators=100, score=-0.2242311536709134, total=  18.0s
# [CV] max_depth=80, max_features=15, min_samples_split=3, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=3, n_estimators=100, score=-0.07912989859352115, total=  16.3s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=10, score=-0.049717554901826944, total=   1.6s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=10, score=-0.175138609497407, total=   1.5s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=10, score=-0.1303779592823795, total=   1.5s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=10, score=-0.20091060376468972, total=   1.8s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=10, score=-0.06695437474137744, total=   1.5s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=50, score=-0.03394413498690474, total=   7.8s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=50, score=-0.15696172655650598, total=   8.3s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=50, score=-0.10837215055800398, total=   8.0s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=50, score=-0.1987226568381728, total=   7.7s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=50, score=-0.057597674836089574, total=   7.9s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=100, score=-0.038190734730356724, total=  16.1s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=100, score=-0.1457775606655578, total=  15.7s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=100, score=-0.10118826254093016, total=  15.6s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=100, score=-0.1783854000826417, total=  15.9s
# [CV] max_depth=80, max_features=15, min_samples_split=5, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=5, n_estimators=100, score=-0.06019744559716478, total=  15.7s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=10, score=-0.01555671968052108, total=   1.4s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=10, score=-0.0776549144056089, total=   1.4s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=10, score=-0.06959673720688508, total=   1.8s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=10, score=-0.095821483668739, total=   1.4s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=10, score=-0.026870324089961928, total=   1.4s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=50, score=0.002702906385333881, total=   7.2s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=50, score=-0.056024253889890296, total=   7.1s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=50, score=-0.043183892159687876, total=   7.5s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=50, score=-0.08381148336885791, total=   7.4s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=50, score=-0.014140333419218276, total=   7.5s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=100, score=0.0011932929524749447, total=  15.4s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=100, score=-0.052010894516641315, total=  15.6s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=100, score=-0.039344945551307964, total=  15.0s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=100, score=-0.07416869693348427, total=  15.5s
# [CV] max_depth=80, max_features=15, min_samples_split=10, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=10, n_estimators=100, score=-0.012479984596290405, total=  15.3s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=10, score=0.03344497617768594, total=   1.3s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=10, score=0.034638477849589955, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=10, score=0.04108784021969014, total=   1.3s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=10, score=0.02534215662360284, total=   1.3s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=10, score=0.04107645434941354, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=50, score=0.0431289058792268, total=   6.7s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=50, score=0.049085031272810054, total=   6.5s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=50, score=0.04367389637358432, total=   6.4s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=50, score=0.03893406363220353, total=   6.7s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=50, score=0.048196642129414435, total=   6.5s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=100, score=0.042134637251791784, total=  13.1s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=100, score=0.053418523049637234, total=  12.7s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=100, score=0.04592932306995989, total=  13.0s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=100, score=0.04448834124558698, total=  13.3s
# [CV] max_depth=80, max_features=15, min_samples_split=30, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=30, n_estimators=100, score=0.050124521209439, total=  13.1s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=10, score=0.04390198729561268, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=10, score=0.05683053946354655, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=10, score=0.05566597199640222, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=10, score=0.05312128545684325, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=10, score=0.05362867582005704, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=50, score=0.04926655403832958, total=   6.1s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=50, score=0.06608547198215076, total=   6.3s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=50, score=0.059925851618535364, total=   6.3s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=50, score=0.06343088573028988, total=   6.3s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=50, score=0.05891633875327407, total=   6.6s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=100, score=0.04865415102488824, total=  26.1s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=100, score=0.06894563114114571, total=  25.8s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=100, score=0.060577892688857826, total=  12.5s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=100, score=0.06481947992152182, total=  12.7s
# [CV] max_depth=80, max_features=15, min_samples_split=50, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=50, n_estimators=100, score=0.06000986958793386, total=  13.2s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=10, score=0.04979403330529597, total=   1.2s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=10, score=0.06925623137057568, total=   1.1s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=10, score=0.06505305896474156, total=   1.1s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=10, score=0.07054346590426608, total=   1.1s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=10
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=10, score=0.05885784846986508, total=   1.3s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=50, score=0.05159263727325647, total=   5.7s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=50, score=0.07409786335789303, total=   6.0s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=50, score=0.06690106022621722, total=   5.9s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=50, score=0.07359085565995849, total=   5.8s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=50
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=50, score=0.06285393905996772, total=   5.9s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=100, score=0.051404758048525734, total=  12.0s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=100, score=0.07608373108790434, total=  12.8s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=100, score=0.0671252700508177, total=  11.3s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=100, score=0.07500474251731115, total=  11.3s
# [CV] max_depth=80, max_features=15, min_samples_split=100, n_estimators=100
# [CV]  max_depth=80, max_features=15, min_samples_split=100, n_estimators=100, score=0.0638223007381199, total=  11.2s
# [Parallel(n_jobs=1)]: Done 1440 out of 1440 | elapsed: 103.9min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=1024, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [10, 50, 100], 'max_depth': [5, 10, 30, 80], 'max_features': [1, 3, 8, 15], 'min_samples_split': [3, 5, 10, 30, 50, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='r2', verbose=10)

# %% [markdown]
# Tuning the model took a very long time, (~5 hours), but now having tuned the model, we can look at the parameters that best fit the dataset.

# %%
g_src.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': 3,
#  'min_samples_split': 100,
#  'n_estimators': 100}

# %% [markdown]
# We can use these obtained parameters to train a Tuned model.

# %%
tuned_rf_model = RandomForestRegressor(max_depth=30, max_features=3, min_samples_split=100, n_estimators=100);

# %%
tuned_rf_model.fit(X_train, y_train);

# %%
y_preds_tuned = tuned_rf_model.predict(X_test);

# %%
r2_score(y_test, y_preds_tuned)
# Out:
# 0.069935792705576483

# %% [markdown]
# ### Results
#
# Our final results on the different trained models are:
#
# - 0.0791369487837 with *SVM Regressor*
# - -0.0823391370849 with *Default Random Forest Regressor*
# - 0.069935792705576483 with *Tuned Random Forest Regressor*
#
# The final **R2** score is better than that obtained with a SVM and with the default Random Forest. There is not a lot of difference between the results of the SVM and Random Forest, and our Grid Search shows that the SVM could be tuned to obtain better results as well.
#
# With Random Forest, we can look at Feature Importance of the attributes that were used to train the model.

# %%
pd.DataFrame(list(zip(transaction_data_only.columns[2:], tuned_rf_model.feature_importances_)), columns=['Attribute', 'Feature Importance']).sort_values(by='Feature Importance', ascending=False)
# Out:
#                 Attribute  Feature Importance
# 8                  income            0.559043
# 7                     age            0.170284
# 14             member_day            0.095127
# 12            member_year            0.061136
# 13           member_month            0.054897
# 10               gender_M            0.031138
# 9                gender_F            0.026430
# 11               gender_O            0.001946
# 0               is_reward            0.000000
# 1               is_amount            0.000000
# 2               has_offer            0.000000
# 3   event_offer_completed            0.000000
# 4    event_offer_received            0.000000
# 5      event_offer_viewed            0.000000
# 6       event_transaction            0.000000

# %% [markdown]
# To predict **price**, it's shown that **income** and **age** are the highest contributors. Surprisingly, **gender** is not as important, although we previously saw some correlation in them. Our boolean attributes are all set to 0, as they should be because the values will be the same for all rows.
#
# ***It answers our 3rd question, on which attributes most influence price. Income and Age are most likely to influence how much someone spends at Starbucks.***

# %% [markdown]
# #### Improving the work
#
# We obtained good results with our model after tuning it with a Random Forest. However, there are some areas that could use improvement. The areas I would like to try to work on as an update to this work are:
#
# 1. Instead of relying only on Random Forests, we should compare them against a different model as well. I did use a SVM for an initial benchmark, and it showed promising results with default parameters. This model should have been fine tuned using a Grid Search, to try out different types of kernels, both polynomial and RBF. A non-linear kernel makes more sense for this type of data because there are a lot of numerical attributes.
#
# 2. We can make the Status value of auser's response to an offer more granular. The values we obtained are weather a user has viewed, or not viewed an offer, while completing it. There is more information that is availabile in the transcript, such as if the offer was not completed at all, but started. The number of transactions related to an offer could be binned and also separated into individual columns.
#
# 2. We could also look at the value of status and see how different demographics relate to it. This could be done by using a supervised learning model to try to train on learning the Status value. To train such a model, we have a lot of available data, because we would be using the transcript records, which would be coupled with information from both profile (demographics) and portfolio (offer details).

# %% [markdown]
# ### Deploying
#
# The code in the Jupyter Notebook will be posted on GitHub, with a ReadMe file to provide information on how to run the code locally.

# %% [markdown]
# In our Data Analysis, we answered three questions that we set out to explore with the Starbucks Transactions dataset.
#
# 1. Gender does influence how much a person spends at Starbucks. While Men tend to have more purchases, Women tend to make more expensive purchases. On average, women spend around $6 more per purchase at Starbucks.
#
# 2. A significant portion of members do view and complete offers at Starbucks. Based on the dataset, 25% of individuals actually receive, view, and complete the offers by making purchases associated with the offer. Furthermore, 10% of individuals complete offers without actually viewing them first, completing them unintentionally.
#
# 3. The attributes that most contribute to how much someone spends at Starbucks are Income and Age. While there are other contributing factors, such as Gender (as we saw previously), Income is the highest influencer with over 55% importance when trying to predict the price of a coffee.
#
# These are very interesting findings, and with the data we cleaned and processed, we can use them to look at many other trends. With this data,
#
# *How would YOU use it to answer your own questions about Starbucks Purchases?*
